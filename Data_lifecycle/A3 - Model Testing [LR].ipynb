# %% [markdown]
# # Model Testing

# %%
y_pred = final_model.predict(X_test)

# %%
y_test = y_test.squeeze()

# %%
pred_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
pred_df
# Out:
#          Actual  Predicted
# 12645  0.083056   0.110566
# 14424  0.025257   0.087418
# 4928   0.104591   0.133685
# 5458   0.221801   0.129964
# 8011   0.070050   0.095571
# ...         ...        ...
# 8013   0.054993   0.113514
# 7346   0.192367   0.218266
# 3022   0.045119   0.076212
# 13971  0.090630   0.122906
# 12516  0.071836   0.084274
#
# [1996 rows x 2 columns]

# %%
#Visualizing the actual versus predicted values
xax = range(len(y_test))
plt.plot(xax, y_test, label='actual')
plt.plot(xax, y_pred, label='predictions')
plt.title("Stepwise Regression Actual vs. Predictions")
plt.legend()
plt.tight_layout()
plt.savefig('srm_pred.png')
plt.show()
