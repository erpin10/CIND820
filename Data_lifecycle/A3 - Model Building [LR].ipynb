# %% [markdown]
# # Model Building

# %%
model_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                                             OLS Regression Results
# ...
# Dep. Variable:     Number of outpatient emergency department visits per 1000 long-stay resident days   R-squared:                       0.294
# Model:                                                                                           OLS   Adj. R-squared:                  0.291
# Method:                                                                                Least Squares   F-statistic:                     125.2
# Date:                                                                               Mon, 07 Mar 2022   Prob (F-statistic):               0.00
# Time:                                                                                       09:16:18   Log-Likelihood:                 13947.
# ...

# %% [markdown]
# Note the following general observations: <br>
# - R^2 = 0.294, which remains relatively low
# - F-value is statistically significant
# - There are multiple measures with a p-value > 0.05
# - The statsmodel regression notes state that there is potentially strong multicollinearity in model due to the condition number
#
# Stepwise regression will be performed to increase stability of the model. Alpha = 0.05 so coefficients with p-value > 0.05 will be removed.

# %%
#Performing stepwise regression on largest p-value attribute
#Removing 'Percentage of long-stay residents who lose too much weight' - p-value of 0.966
Z_drop = Z.drop(['Percentage of long-stay residents who lose too much weight'], axis=1)
model_3 = sm.OLS(y_2, Z_drop, missing='drop').fit()
model_3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                                             OLS Regression Results
# ...
# Dep. Variable:     Number of outpatient emergency department visits per 1000 long-stay resident days   R-squared:                       0.294
# Model:                                                                                           OLS   Adj. R-squared:                  0.291
# Method:                                                                                Least Squares   F-statistic:                     129.1
# Date:                                                                               Mon, 07 Mar 2022   Prob (F-statistic):               0.00
# Time:                                                                                       09:16:21   Log-Likelihood:                 13947.
# ...

# %% [markdown]
# Model 3: Removing 'Percentage of long-stay residents who lose too much weight' attribute results:
# - R^2 remains at 0.294
# - Condition number remains at 2.27e+03

# %%
#Removing 'Number of Citations from Infection Control Inspections' 
Z_drop_1 = Z_drop.drop(['Number of Citations from Infection Control Inspections'], axis=1)
model_4 = sm.OLS(y_2, Z_drop_1, missing='drop').fit()
model_4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                                             OLS Regression Results
# ...
# Dep. Variable:     Number of outpatient emergency department visits per 1000 long-stay resident days   R-squared:                       0.294
# Model:                                                                                           OLS   Adj. R-squared:                  0.291
# Method:                                                                                Least Squares   F-statistic:                     133.3
# Date:                                                                               Mon, 07 Mar 2022   Prob (F-statistic):               0.00
# Time:                                                                                       09:16:23   Log-Likelihood:                 13947.
# ...

# %% [markdown]
# Model 4: Removing 'Number of Citations from Infection Control Inspections' attribute results:
# - R^2 remains at 0.294
# - Condition number decreased minimally to 2.26e+03

# %%
#Removing 'Total Number of Health Deficiencies' 
Z_drop_2 = Z_drop_1.drop(['Total Number of Health Deficiencies'], axis=1)
model_5 = sm.OLS(y_2, Z_drop_2, missing='drop').fit()
model_5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                                             OLS Regression Results
# ...
# Dep. Variable:     Number of outpatient emergency department visits per 1000 long-stay resident days   R-squared:                       0.294
# Model:                                                                                           OLS   Adj. R-squared:                  0.291
# Method:                                                                                Least Squares   F-statistic:                     137.8
# Date:                                                                               Mon, 07 Mar 2022   Prob (F-statistic):               0.00
# Time:                                                                                       09:16:24   Log-Likelihood:                 13947.
# ...

# %% [markdown]
# Model 5: Removing 'Total Number of Health Deficiencies' attribute results:
# - R^2 remains at 0.294
# - Condition number reduced slightly at 2.2e+03

# %%
#Removing 'COVID-19 Deaths Per Occupied Beds' 
Z_drop_3 = Z_drop_2.drop(['COVID-19 Deaths Per Occupied Beds'], axis=1)
model_6 = sm.OLS(y_2, Z_drop_3, missing='drop').fit()
model_6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                                             OLS Regression Results
# ...
# Dep. Variable:     Number of outpatient emergency department visits per 1000 long-stay resident days   R-squared:                       0.294
# Model:                                                                                           OLS   Adj. R-squared:                  0.292
# Method:                                                                                Least Squares   F-statistic:                     142.5
# Date:                                                                               Mon, 07 Mar 2022   Prob (F-statistic):               0.00
# Time:                                                                                       09:16:26   Log-Likelihood:                 13947.
# ...

# %% [markdown]
# Model 6: Removing 'COVID-19 Deaths Per Occupied Beds' attribute results:
# - R^2 remains at 0.294
# - Condition number is not notable

# %%
#Removing 'Percentage of long-stay residents experiencing one or more falls with major injury' 
Z_drop_4 = Z_drop_3.drop(['Percentage of long-stay residents experiencing one or more falls with major injury'], axis=1)
model_7 = sm.OLS(y_2, Z_drop_4, missing='drop').fit()
model_7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                                             OLS Regression Results
# ...
# Dep. Variable:     Number of outpatient emergency department visits per 1000 long-stay resident days   R-squared:                       0.294
# Model:                                                                                           OLS   Adj. R-squared:                  0.292
# Method:                                                                                Least Squares   F-statistic:                     147.7
# Date:                                                                               Mon, 07 Mar 2022   Prob (F-statistic):               0.00
# Time:                                                                                       09:16:28   Log-Likelihood:                 13947.
# ...

# %% [markdown]
# Model 7: Removing 'Percentage of long-stay residents experiencing one or more falls with major injury' attribute results:
# - R^2 remains at 0.294

# %%
#Removing 'Percentage of long-stay residents who were physically restrained' 
Z_drop_5 = Z_drop_4.drop(['Percentage of long-stay residents who were physically restrained'], axis=1)
model_8 = sm.OLS(y_2, Z_drop_5, missing='drop').fit()
model_8.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                                             OLS Regression Results
# ...
# Dep. Variable:     Number of outpatient emergency department visits per 1000 long-stay resident days   R-squared:                       0.294
# Model:                                                                                           OLS   Adj. R-squared:                  0.292
# Method:                                                                                Least Squares   F-statistic:                     153.1
# Date:                                                                               Mon, 07 Mar 2022   Prob (F-statistic):               0.00
# Time:                                                                                       09:16:29   Log-Likelihood:                 13947.
# ...

# %% [markdown]
# Model 8: Removing 'Percentage of long-stay residents who were physically restrained' attribute results:
# - R^2 remains at 0.294

# %%
#Removing 'Adjusted Nurse Aide Staffing Hours per Resident per Day' 
Z_drop_6 = Z_drop_5.drop(['Adjusted Nurse Aide Staffing Hours per Resident per Day'], axis=1)
model_9 = sm.OLS(y_2, Z_drop_6, missing='drop').fit()
model_9.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                                             OLS Regression Results
# ...
# Dep. Variable:     Number of outpatient emergency department visits per 1000 long-stay resident days   R-squared:                       0.294
# Model:                                                                                           OLS   Adj. R-squared:                  0.292
# Method:                                                                                Least Squares   F-statistic:                     159.0
# Date:                                                                               Mon, 07 Mar 2022   Prob (F-statistic):               0.00
# Time:                                                                                       09:16:31   Log-Likelihood:                 13947.
# ...

# %% [markdown]
# Model 9: Removing 'Adjusted Nurse Aide Staffing Hours per Resident per Day' attribute results:
# - R^2 remains at 0.294

# %%
#Removing 'Confirmed COVID-19 Cases Per Occupied Bed' 
Z_drop_7 = Z_drop_6.drop(['Confirmed COVID-19 Cases Per Occupied Beds'], axis=1)
model_10 = sm.OLS(y_2, Z_drop_7, missing='drop').fit()
model_10.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                                             OLS Regression Results
# ...
# Dep. Variable:     Number of outpatient emergency department visits per 1000 long-stay resident days   R-squared:                       0.294
# Model:                                                                                           OLS   Adj. R-squared:                  0.292
# Method:                                                                                Least Squares   F-statistic:                     165.4
# Date:                                                                               Mon, 07 Mar 2022   Prob (F-statistic):               0.00
# Time:                                                                                       09:16:32   Log-Likelihood:                 13947.
# ...

# %% [markdown]
# Model 10: Removing 'Confirmed COVID-19 Cases Per Occupied Bed' attribute results:
# - R^2 remains at 0.294

# %%
#Removing 'Registered Nurse turnover' 
Z_drop_8 = Z_drop_7.drop(['Registered Nurse turnover'], axis=1)
model_11 = sm.OLS(y_2, Z_drop_8, missing='drop').fit()
model_11.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                                             OLS Regression Results
# ...
# Dep. Variable:     Number of outpatient emergency department visits per 1000 long-stay resident days   R-squared:                       0.293
# Model:                                                                                           OLS   Adj. R-squared:                  0.292
# Method:                                                                                Least Squares   F-statistic:                     172.2
# Date:                                                                               Mon, 07 Mar 2022   Prob (F-statistic):               0.00
# Time:                                                                                       09:16:34   Log-Likelihood:                 13947.
# ...

# %% [markdown]
# Model 11: Removing 'Registered Nurse turnover' attribute results:
# - R^2 reduced to 0.293

# %%
#Removing 'Ownership Type_1' 
Z_drop_9 = Z_drop_8.drop(['Ownership Type_1'], axis=1)
model_12 = sm.OLS(y_2, Z_drop_9, missing='drop').fit()
model_12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                                             OLS Regression Results
# ...
# Dep. Variable:     Number of outpatient emergency department visits per 1000 long-stay resident days   R-squared:                       0.293
# Model:                                                                                           OLS   Adj. R-squared:                  0.292
# Method:                                                                                Least Squares   F-statistic:                     179.7
# Date:                                                                               Mon, 07 Mar 2022   Prob (F-statistic):               0.00
# Time:                                                                                       09:16:35   Log-Likelihood:                 13946.
# ...

# %% [markdown]
# Model 12: Removing 'Ownership Type_1' attribute results:
# - R^2 remains at 0.293

# %%
#Removing 'Percentage of long-stay residents assessed and appropriately given the seasonal influenza vaccine' 
Z_drop_10 = Z_drop_9.drop(['Percentage of long-stay residents assessed and appropriately given the seasonal influenza vaccine'], axis=1)
model_13 = sm.OLS(y_2, Z_drop_10, missing='drop').fit()
model_13.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                                             OLS Regression Results
# ...
# Dep. Variable:     Number of outpatient emergency department visits per 1000 long-stay resident days   R-squared:                       0.293
# Model:                                                                                           OLS   Adj. R-squared:                  0.292
# Method:                                                                                Least Squares   F-statistic:                     187.8
# Date:                                                                               Mon, 07 Mar 2022   Prob (F-statistic):               0.00
# Time:                                                                                       09:16:37   Log-Likelihood:                 13945.
# ...

# %% [markdown]
# Model 13: Removing 'Percentage of long-stay residents assessed and appropriately given the seasonal influenza vaccine' attribute results:
# - R^2 remains at 0.293

# %%
#Removing 'Percentage of long-stay residents who have depressive symptoms' 
Z_drop_11 = Z_drop_10.drop(['Percentage of long-stay residents who have depressive symptoms'], axis=1)
model_14 = sm.OLS(y_2, Z_drop_11, missing='drop').fit()
model_14.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                                             OLS Regression Results
# ...
# Dep. Variable:     Number of outpatient emergency department visits per 1000 long-stay resident days   R-squared:                       0.293
# Model:                                                                                           OLS   Adj. R-squared:                  0.292
# Method:                                                                                Least Squares   F-statistic:                     196.7
# Date:                                                                               Mon, 07 Mar 2022   Prob (F-statistic):               0.00
# Time:                                                                                       09:16:38   Log-Likelihood:                 13945.
# ...

# %% [markdown]
# Model 14: Removing 'Percentage of long-stay residents assessed and appropriately given the seasonal influenza vaccine' attribute results:
# - R^2 remains at 0.293

# %%
#Removing 'Number of Facility Reported Incidents' 
Z_drop_12 = Z_drop_11.drop(['Number of Facility Reported Incidents'], axis=1)
model_15 = sm.OLS(y_2, Z_drop_12, missing='drop').fit()
model_15.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                                             OLS Regression Results
# ...
# Dep. Variable:     Number of outpatient emergency department visits per 1000 long-stay resident days   R-squared:                       0.293
# Model:                                                                                           OLS   Adj. R-squared:                  0.292
# Method:                                                                                Least Squares   F-statistic:                     206.4
# Date:                                                                               Mon, 07 Mar 2022   Prob (F-statistic):               0.00
# Time:                                                                                       09:16:40   Log-Likelihood:                 13944.
# ...

# %% [markdown]
# Model 15: Removing 'Number of Facility Reported Incidents' attribute results:
# - R^2 remains at 0.293

# %%
#Removing 'Total Number of Fire Safety Deficiencies' 
Z_drop_13 = Z_drop_12.drop(['Total Number of Fire Safety Deficiencies'], axis=1)
model_16 = sm.OLS(y_2, Z_drop_13, missing='drop').fit()
model_16.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                                             OLS Regression Results
# ...
# Dep. Variable:     Number of outpatient emergency department visits per 1000 long-stay resident days   R-squared:                       0.293
# Model:                                                                                           OLS   Adj. R-squared:                  0.292
# Method:                                                                                Least Squares   F-statistic:                     217.1
# Date:                                                                               Mon, 07 Mar 2022   Prob (F-statistic):               0.00
# Time:                                                                                       09:16:41   Log-Likelihood:                 13943.
# ...

# %% [markdown]
# Model 16: Removing 'Total Number of Fire Safety Deficiencies' attribute results:
# - R^2 remains at 0.293
#
# P-values are now all significant. Model attributes that are important to accuracy of prediction retained.

# %%
#80-20 test/train split
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(Z_drop_13, y_2, random_state=0, test_size=0.2)

# %%
#Fit the resulting model 
final_model = sm.OLS(y_train, X_train).fit()
final_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                                             OLS Regression Results
# ...
# Dep. Variable:     Number of outpatient emergency department visits per 1000 long-stay resident days   R-squared:                       0.296
# Model:                                                                                           OLS   Adj. R-squared:                  0.295
# Method:                                                                                Least Squares   F-statistic:                     176.4
# Date:                                                                               Mon, 07 Mar 2022   Prob (F-statistic):               0.00
# Time:                                                                                       09:16:56   Log-Likelihood:                 11157.
# ...

# %% [markdown]
# <b>Based on this model, the attributes with the most effect include: <br></b>
# Average Residents per Day: With a unit increase in Average Residents per Day, there is a -0.144 decrease in the Emergency Department Visit Rate. <br>
# Long-Stay QM Rating (1.0): With a unit increase in the 1/5 (or lowest) Long-Stay QM Rating, there is an increase in the Emergency Department Visit Rate. <br>
# Percentage of long-stay residents whose need for help with daily activities has increase: With a unit increase in the percentage of long-stay residents who need additional help, there is a -0.1155 decrease in Emergency Dpeartment Visit Rate.<br>
# Percentage of long-stay resident who received an antipsychotic medication: With a unit increase in the percentage of patients receiving a anti-psychotic medication, there is a -0.1043 decrease in the Emergency Department Visit rate. <br>
